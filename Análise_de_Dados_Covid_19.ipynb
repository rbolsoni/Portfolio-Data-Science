# %% [markdown]
# <a href="https://colab.research.google.com/github/rbolsoni/Portfolio-Data-Science/blob/master/An%C3%A1lise_de_Dados_Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://i.ibb.co/NSNJF2V/3488995.jpg)
#
#
# [![author](https://img.shields.io/badge/author-rbolsoni-orange.svg)](www.linkedin.com/in/rafabolsoni)
# [![author](https://img.shields.io/badge/see%20more-projects-brightgreen.svg)](https://github.com/rbolsoni)

# %% [markdown]
# # Introdução
#
# **Coronavírus** e **Novo Coronavírus** são os nomes dos vírus, e **CoViD-19** é o nome da doença provocada pelo Novo Coronavírus.
#
# **Identificados nos anos 1960**, os Coronavírus pertencem à subfamília taxonômica Orthocoronavirinae da família Coronaviridae, da ordem Nidovirales. Eles se subdividem em vários gêneros, espécies e cepas. Alguns atacam animais, outros afetam a espécie humana, causando desde doenças leves, com sintomas parecidos ao de um resfriado comum, até doenças graves como a SARS, a MERS e atual CoViD-19.
#
# **O Coronavírus ficou conhecido mundialmente em 2002** quando causou a SARS - a Síndrome Respiratória Aguda Grave - doença que se espalhou para vários países a partir da China fazendo cerca de 800 vítimas - 10% das 8.000 pessoas que se infectaram.
#
# **Uma nova cepa de Coronavírus, surgida na Jordânia em 2012**, causou a MERS - a Síndrome Respiratória do Oriente Médio - enfermidade que se disseminou no Oriente Médio e chegou até a Coréia do Sul, vitimando 35% das 2.500 pessoas que se contaminaram, doença que apresentou o impressionante índice de letalidade de 35%.
#
# E na China, em 2019, surgiu outra linhagem do vírus - o Novo Coronavírus - responsável pela doença CoViD-19 que está provocando esta pandemia. **Seu índice de mortalidade é de 3 a 4%**, mas a sua capacidade de **transmissão é muito maior do que as dos demais vírus, pois ele se transmite mesmo por pessoas sem nenhum tipo de sintoma** e tem uma capacidade e velocidade de reprodução muito superior as dos demais.

# %% [markdown]
# ## Covid-19 ou Coronavirus?
#
# **O que é COVID-19?**
#
# A COVID-19 é uma doença causada pelo coronavírus SARS-CoV-2, que apresenta um quadro clínico que varia de infecções assintomáticas a quadros respiratórios graves. De acordo com a Organização Mundial de Saúde (OMS), a maioria dos pacientes com COVID-19 (cerca de 80%) podem ser assintomáticos e cerca de 20% dos casos podem requerer atendimento hospitalar por apresentarem dificuldade respiratória e desses casos aproximadamente 5% podem necessitar de suporte para o tratamento de insuficiência respiratória (suporte ventilatório).
#
# **O que é o coronavírus?**
#
# Coronavírus é uma família de vírus que causam infecções respiratórias. O novo agente do coronavírus foi descoberto em 31/12/19 após casos registrados na China. Provoca a doença chamada de coronavírus (COVID-19).
#
# Os primeiros coronavírus humanos foram isolados pela primeira vez em 1937. No entanto, foi em 1965 que o vírus foi descrito como coronavírus, em decorrência do perfil na microscopia, parecendo uma coroa.
#
# A maioria das pessoas se infecta com os coronavírus comuns ao longo da vida, sendo as crianças pequenas mais propensas a se infectarem com o tipo mais comum do vírus. Os coronavírus mais comuns que infectam humanos são o alpha coronavírus 229E e NL63 e beta coronavírus OC43, HKU1.

# %% [markdown]
# ## Sintomas
#
# **Quais são os sintomas**
#
# Os sintomas da COVID-19 podem variar de um simples resfriado até uma pneumonia severa. Sendo os sintomas mais comuns:
#
# * Tosse
# * Febre
# * Coriza
# * Dor de garganta
# * Dificuldade para respirar

# %% [markdown]
# ## Transmissão
# **Como é transmitido**
#
# A transmissão acontece de uma pessoa doente para outra ou por contato próximo por meio de:
# * Toque do aperto de mão;
# * Gotículas de saliva;
# * Espirro;
# * Tosse;
# * Catarro;
# * Objetos ou superfícies contaminadas, como celulares, mesas, maçanetas, brinquedos, teclados de computador etc.

# %% [markdown]
# # Origem dos dados
#
# Os dados foram tirados repósitorio no Github do [OurWorldInData](https://ourworldindata.org/) que é uma organização sem fins lucrativos que coleta e fornece gratuitamente dados sobre principalmente "pobreza, doença, fome, mudança climática, guerra, riscos existenciais e desigualdade". Os dados mundiais sobre Covid-19 são atualizados diariamente pela organização que é uma das mais respeitadas no mundo relacionada ao fornecimento de dados. Você pode acessar esses dados públicos atualizados [aqui](https://github.com/owid/covid-19-data/tree/master/public/data).
#
# As informações dessa análise foram atualizadas dia 30/06/2020.

# %% [markdown]
# ## Biblioteca
#
# A compreensão dos dados é tão importante quanto a análise exploratória, pois se não entender o que significa e de onde vem os dados não poderá realizar uma análise plena.
#
# Coluna|Descrição|Origem
# ------|-----------|------
# `iso_code`|Letras códigos dos países com base na ISO 3166-1 alpha-3|International Organization for Standardization
# `continent`|Continente|Our World in Data
# `location`|Localização Geográfica|Our World in Data
# `date`|Data da observação|Our World in Data
# `total_cases`|Total de casos confirmados de COVID-19|Centro Europeu de Prevenção e Controle de Doenças
# `new_cases`|Novos casos confirmados de COVID-19|Centro Europeu de Prevenção e Controle de Doenças
# `total_deaths`|Total de mortes atribuidas ao COVID-19|Centro Europeu de Prevenção e Controle de Doenças
# `new_deaths`|Novas mortes atribuidas ao COVID-19|Centro Europeu de Prevenção e Controle de Doenças
# `total_cases_per_million`|Total de casos confirmados de COVID-19 por 1,000,000 de habitantes|Centro Europeu de Prevenção e Controle de Doenças
# `new_cases_per_million`|Novos casos confirmados de COVID-19 por 1,000,000 de habitantes|Centro Europeu de Prevenção e Controle de Doenças
# `total_deaths_per_million`|Total de mortes atribuidas ao COVID-19 pr 1,000,000 de habitantes|Centro Europeu de Prevenção e Controle de Doenças
# `new_deaths_per_million`|Novas mortes atribuidas ao COVID-19 por 1,000,000 de habitantes|Centro Europeu de Prevenção e Controle de Doenças
# `total_tests`|Total de testes para COVID-19|National government reports
# `new_tests`|Novos testes para COVID-19|National government reports
# `new_tests_smoothed`|Novos testes para COVID-19 (suavizados por 7 dias).|National government reports
# `total_tests_per_thousand`|Total testes para COVID-19 por 1,000 habitantes|National government reports
# `new_tests_per_thousand`|New testes para COVID-19 por 1,000 habitantes|National government reports
# `new_tests_smoothed_per_thousand`|New testes para COVID-19 (suavizados por 7 dias) por 1,000 habitantes|National government reports
# `tests_units`|Unidades usadas pelo local para relatar seus dados de teste|National government reports
# `stringency_index`|Índice de Estresse da Resposta do Governo|Oxford COVID-19 Government Response Tracker, Blavatnik School of Government
# `population`|População em 2020|United Nations
# `population_density`|Densidade demografica (em km²)|World Bank
# `median_age`|Média de idade da população|UN Population Division
# `aged_65_older`|Proporção da população com 65 anos ou mais, ano mais recente disponível|Banco Mundial
# `aged_70_older`|Percentagem da população com 70 anos ou mais em 2015 | Nações Unidas, Departamento de Assuntos Econômicos e Sociais, Divisão de População (2017)
# `gdp_per_capita`|Produto interno bruto em paridade de poder de compra (dólares internacionais constantes de 2011), ano mais recente disponível | Banco Mundial
# `extreme_poverty`|Percentagem da população que vive em extrema pobreza, ano mais recente disponível desde 2010 | Banco Mundial -
# `cvd_death_rate`|Taxa de mortalidade por doenças cardiovasculares em 2017 | Rede Colaborativa Global de Carga de Doenças
# `diabetes_prevalence`|Prevalência de diabetes (% da população entre 20 e 79 anos) em 2017 | Banco Mundial
# `female_smokers` | Percentagem de mulheres que fumam, ano mais recente disponível | Banco Mundial
# `male_smokers` | Percentagem de homens que fuma, ano mais recente disponível | Banco Mundial
# `hospital_beds_per_thousand` | Percentagem da população com instalações básicas de lavagem das mãos nas instalações, no ano mais recente disponível | Divisão de Estatística das Nações Unidas
# `hospital_beds_per_thousand` | Camas de hospital por 1.000 pessoas, ano mais recente disponível desde 2010 | OCDE, Eurostat, Banco Mundial, registros do governo nacional e outras fontes
# `life_expectancy` | Expectativa de vida no nascimento em 2019 | James C. Riley, Clio Infra, Divisão de População das Nações Unidas

# %% [markdown]
# # Análise Exploratória
#
# Agora iremos importar as bibliotecas que iremos utilizas e depois vamos visualizar a composição geral do nosso dataframe.

# %%
#importando as bibliotecas e dataframe
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set()

DATA_PATH = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'
df = pd.read_csv(DATA_PATH)

# %%
#Vamos ver as 5 primeiras entradas

df.head()
# Out:
#   iso_code continent  ... hospital_beds_per_thousand life_expectancy
# 0      AFG      Asia  ...                        0.5           64.83
# 1      AFG      Asia  ...                        0.5           64.83
# 2      AFG      Asia  ...                        0.5           64.83
# 3      AFG      Asia  ...                        0.5           64.83
# 4      AFG      Asia  ...                        0.5           64.83
#
# [5 rows x 34 columns]

# %%
#o tamanho do dataframe

df.shape
# Out:
# (27169, 34)

# %%
# ver o nome das colunas

df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
#tipos de dados

df.dtypes
# Out:
# iso_code                            object
# continent                           object
# location                            object
# date                                object
# total_cases                        float64
# new_cases                          float64
# total_deaths                       float64
# new_deaths                         float64
# total_cases_per_million            float64
# new_cases_per_million              float64
# total_deaths_per_million           float64
# new_deaths_per_million             float64
# total_tests                        float64
# new_tests                          float64
# total_tests_per_thousand           float64
# new_tests_per_thousand             float64
# new_tests_smoothed                 float64
# new_tests_smoothed_per_thousand    float64
# tests_units                         object
# stringency_index                   float64
# population                         float64
# population_density                 float64
# ...

# %%
# % de dados faltantes

(df.isnull().sum() / df.shape[0]).sort_values(ascending=False) * 100
# Out:
# new_tests                          74.182828
# new_tests_per_thousand             74.182828
# total_tests_per_thousand           71.677441
# total_tests                        71.677441
# new_tests_smoothed_per_thousand    69.376575
# new_tests_smoothed                 69.376575
# tests_units                        67.115883
# handwashing_facilities             59.176071
# extreme_poverty                    40.341843
# male_smokers                       28.494211
# female_smokers                     27.654213
# stringency_index                   19.926226
# hospital_beds_per_thousand         17.413535
# aged_65_older                      10.985720
# gdp_per_capita                     10.730068
# aged_70_older                      10.167634
# median_age                          9.703809
# cvd_death_rate                      9.594244
# diabetes_prevalence                 6.654249
# population_density                  4.375297
# life_expectancy                     1.395128
# ...

# %%
# transformar a coluna 'date' no formato datetime

df.date = pd.to_datetime(df.date)
df.date.max()
df.set_index('date', inplace=True)

# %% [markdown]
# ### Informações estatísticas gerais
#
# Agora que os dados estão no formato correto, iremos ver algumas informações estatísticas gerais dos nossos dados.

# %%
df.describe()
# Out:
#         total_cases      new_cases  ...  hospital_beds_per_thousand  life_expectancy
# count  2.758600e+04   27586.000000  ...                22952.000000     27422.000000
# mean   3.511471e+04     786.288335  ...                    3.171080        74.384833
# std    3.520781e+05    6996.074111  ...                    2.571082         7.270999
# min    0.000000e+00  -29726.000000  ...                    0.100000        53.280000
# 25%    1.500000e+01       0.000000  ...                    1.380000        70.780000
# 50%    2.700000e+02       4.000000  ...                    2.540000        75.880000
# 75%    3.036500e+03      74.000000  ...                    4.210000        80.180000
# max    1.084528e+07  200215.000000  ...                   13.800000        86.750000
#
# [8 rows x 29 columns]

# %% [markdown]
# ## Correlação
#
# É uma medida de correlação de postos, ou seja, verifica a semelhança entre as ordens dos dados quando classificados por cada uma das quantidades. Recebe este nome em homenagem ao estatístico britânico Maurice Kendall, que o desenvolveu em 1938.
# A correlação de Kendall leva em consideração apenas a concordância direcional dos chamados pares concordantes e discordantes.
#
# >$ r = \frac{(quantidade-de-pares-concordantes) - (quantidade-de-pares-discordantes)}{n(n-1)/2}$
#
# O mapa de calor abaixo é um elemento visual de correlações, que vai de -1 á 1, onde -1 é considerado nenhuma correlação e 1 é considerado uma perfeita correlação.

# %%
correlation = df[['total_deaths','total_cases',
       'population', 'population_density',
       'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita',
       'cvd_death_rate', 'diabetes_prevalence', 'life_expectancy', 
       'total_deaths_per_million', 'total_cases_per_million', 'extreme_poverty']].corr()

# %%
fig, ax = plt.subplots(figsize=(10,10))   

sns.heatmap(correlation, annot=True, fmt='.2f', ax=ax, square=True, linecolor='white', cmap='RdBu', cbar=False);

# %% [markdown]
# Aqui podemos observar varias correlações e fazer algumas suposições. Colocarei abaixo algumas suposições que tem relação com o assunto o texto, apesar de poder tirar varios outros insights desse mapa de calor.
#
# * `gdp_per_capita`, ou seja *Produto interno bruto em paridade de poder de compra* não tem uma relação direta com a quantidade de casos, nem com a quantidade de mortos no total, mas tem uma relação direta com uma expectativa de vida maior.
#
# * Mesmo paises com uma população maior, não resulta e maior taxa da casos e nem de mortos por milhão.
#
# * Países com uma alta taxa de pobreza extrema tem uma correlação direta com a taxa de morte para cada contaminado.
#
# * Podemos obervar tambem que há uma correlação em quantidade de pessoas com diabetes e a taxa de mortalidade de contaminados.

# %% [markdown]
# # Visualizando os dados mundiais
#
# Os dados em tabelas são ruins para análisar e visualizar as informações com o passar do tempo e para fazer comparações. Por isso vamos agora visualizar todos os dados em formatos de gráficos para termos outras visões com relação a esses dados.

# %%
df_world = df[df['location'] == 'World']

df_world.head()
# Out:
#             iso_code continent  ... hospital_beds_per_thousand  life_expectancy
# date                            ...
# 2019-12-31  OWID_WRL       NaN  ...                      2.705            72.58
# 2020-01-01  OWID_WRL       NaN  ...                      2.705            72.58
# 2020-01-02  OWID_WRL       NaN  ...                      2.705            72.58
# 2020-01-03  OWID_WRL       NaN  ...                      2.705            72.58
# 2020-01-04  OWID_WRL       NaN  ...                      2.705            72.58
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Taxa de mortalidade

# %%
fig, ax = plt.subplots(figsize=[15, 6])

ax.plot(df_world[['total_cases', 'total_deaths']])
ax.set_title('Casos x Mortes')
ax.set_ylabel('Quantidade')
ax.set_xlabel('Tempo')
fig.autofmt_xdate()


plt.tight_layout()
plt.show()

# %%
df_mort = (df_world.total_deaths / df_world.total_cases) * 100
print(df_mort)
# Out:
# date
# 2019-12-31    0.000000
# 2020-01-01    0.000000
# 2020-01-02    0.000000
# 2020-01-03    0.000000
# 2020-01-04    0.000000
#                 ...
# 2020-06-29    4.959696
# 2020-06-30    4.918604
# 2020-07-01    4.882874
# 2020-07-02    4.837448
# 2020-07-03    4.804977
# Length: 186, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(18,6))
ax.plot(df_mort)
ax.set_title('Taxa de mortalidade mundial')
ax.set_ylabel('% de mortalidade')

plt.tight_layout()
plt.show()

# %%
df_top1 = df[(df['location'] == 'United States') | (df['location'] == 'Brazil') | (df['location'] == 'Russia') | (df['location'] == 'India') | (df['location'] == 'United Kingdom')]
df_top_mort1 = (df_top1.total_deaths / df_top1.total_cases) * 100
df_top_mort1.head()
# Out:
# date
# 2019-12-31   NaN
# 2020-01-01   NaN
# 2020-01-02   NaN
# 2020-01-03   NaN
# 2020-01-04   NaN
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(18,6))
ax.plot(df_top_mort1)
ax.plot(df_mort)
ax.set_title('Taxa dos países com mais casos')
ax.set_ylabel('% de mortalidade')



plt.tight_layout()
plt.show()

# %%
df_aux = df.loc['2020-06-30', ['location', 'total_cases']].sort_values(by='total_cases', ascending=False)[1:6]
fig, ax = plt.subplots(figsize=(14,6))

sns.barplot(df_aux.location, df_aux.total_cases, palette='Paired', ax=ax)

ax.set_title('TOP 5 Países com mais casos de COVID-19')
ax.set_xlabel('Países')
ax.set_ylabel('Total de Casos')

plt.tight_layout()

# %%
df_aux = df.loc['2020-06-30', ['location', 'total_deaths']].sort_values(by='total_deaths', ascending=False)[1:6]
fig, ax = plt.subplots(figsize=(14,6))

sns.barplot(df_aux.location, df_aux.total_deaths, palette='pastel', ax=ax)

ax.set_title('TOP 5 Países com mais mortes de COVID-19')
ax.set_xlabel('Países')
ax.set_ylabel('Total de Mortes')

plt.tight_layout()

# %% [markdown]
# #Visualizando dados do Brasil

# %%
df_brazil = df[df['location'] == 'Brazil']

fig, ax = plt.subplots(figsize=[15, 6])

ax.plot(df_brazil[['total_cases', 'total_deaths']])
ax.set_title('Casos x Mortes')
ax.set_ylabel('Quantidade')
ax.set_xlabel('Tempo')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Taxa de mortalidade no Brasil

# %%
df_mort_br = (df_brazil.total_deaths / df_brazil.total_cases) * 100
fig, ax = plt.subplots(figsize=(18,6))
ax.plot(df_mort_br)
ax.set_title('Taxa de mortalidade no Brasil')
ax.set_ylabel('% de mortalidade')

plt.tight_layout()
plt.show()

# %%
df_mort_br = (df_brazil.total_deaths / df_brazil.total_cases) * 100
fig, ax = plt.subplots(figsize=(18,6))
ax.plot(df_mort_br)
ax.plot(df_mort)
ax.set_title('Taxa de mortalidade no Brasil x Mundo')
ax.set_ylabel('% de mortalidade')


plt.tight_layout()
plt.show()

# %% [markdown]
# #Conclusão
#
# O mundo já registra mais de 10 milhões de casos confirmados do novo coronavírus (Sars-CoV-2), de acordo com os dados. São exatos 10.004.643 infecções, sendo que quatro países representam, praticamente, 50% dos registros em valores absolutos.
#
# Os Estados Unidos contabilizam 2.510.323 casos, seguidos pelo Brasil, com 1.313.667, Rússia 633.542 e Índia 528.859. Todos os quatro ainda não conseguiram controlar a curva de contágio, com milhares de novas contaminações sendo registadas diariamente. O número de vítimas do coronavírus passou 500 mil.
#
# A taxa de mortalidade do Brasil segue uma linha muito parecida com a taxa do resto do mundo.
#
# Porém não podemos observar uma queda nos no mundo e nem no Brasil.
